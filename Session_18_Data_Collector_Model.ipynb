# %% [markdown]
# <a href="https://colab.research.google.com/github/SFIComplexityExplorer/Mesa-ABM-Tutorial/blob/main/Session_18_Data_Collector_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Dependencies

# %%
#from google.colab import drive
#drive.mount('/content/drive')

try:
  import mesa
except:
  # !pip install mesa --quiet
import mesa
import numpy as np
import math
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Helper Functions

# %%
def get_distance(pos_1, pos_2):
  '''
  Calculate the Euclidean distance between two positions

  used in trade.move()
  '''

  x1, y1 = pos_1
  x2, y2 = pos_2
  dx = x1 - x2
  dy = y1 - y2
  return math.sqrt(dx**2 + dy**2)

def flatten(list_of_lists):
  '''
  helper function for model datacollector for trade price
  collapses agent price list into one list
  '''
  return [item for sublist in list_of_lists for item in sublist]

def geometric_mean(list_of_prices):
  '''
  find the geometric mean of a list of prices
  '''
  return np.exp(np.log(list_of_prices).mean())

# %% [markdown]
# # Resource Classes

# %%
class Sugar(mesa.Agent):
  """
  Sugar:
  - contains an amount of sugar
  - grows 1 amount of sugar at each turn
  """

  def __init__(self, unique_id, model, pos, max_sugar):
    super().__init__(unique_id, model)
    self.pos = pos
    self.amount = max_sugar
    self.max_sugar = max_sugar


  def step(self):
    '''
    Sugar growth function, adds one unit of sugar each step until
    max amount
    '''
    self.amount = min([self.max_sugar, self.amount+1])

# %%
class Spice(mesa.Agent):
  """
  Spice:
  - contains an amount of spice
  - grows 1 amount of spice at each turn
  """

  def __init__(self, unique_id, model, pos, max_spice):
    super().__init__(unique_id, model)
    self.pos = pos
    self.amount = max_spice
    self.max_spice = max_spice

  def step(self):
    '''
    Spice growth function, adds one unit of spice each step until
    max amout
    '''
    self.amount = min([self.max_spice, self.amount+1])

# %% [markdown]
# # Trader Agent

# %%
class Trader(mesa.Agent):
  """
  Trader:
  - has a metabolism of sugar and spice
  - harvest and trade sugar and spice to survive
  """


  def __init__(self, unique_id, model, pos, moore=False, sugar=0,
               spice=0, metabolism_sugar=0, metabolism_spice=0,
               vision=0):
    super().__init__(unique_id, model)
    self.pos = pos
    self.moore = moore
    self.sugar = sugar
    self.spice = spice
    self.metabolism_sugar = metabolism_sugar
    self.metabolism_spice = metabolism_spice
    self.vision = vision
    self.prices = []
    self.trade_partners = []


  def get_sugar(self, pos):
    '''
    used in self.get_sugar_amount()
    '''

    this_cell = self.model.grid.get_cell_list_contents(pos)
    for agent in this_cell:
      if type(agent) is Sugar:
        return agent
    return None


  def get_sugar_amount(self,pos):
    '''
    used in self.move() as part of self.calculate_welfare()
    '''

    sugar_patch = self.get_sugar(pos)
    if sugar_patch:
      return sugar_patch.amount
    return 0

  def get_spice(self, pos):
    '''
    used in self.get_spice_amount()
    '''

    this_cell = self.model.grid.get_cell_list_contents(pos)
    for agent in this_cell:
      if type(agent) is Spice:
        return agent
    return None

  def get_spice_amount(self, pos):
    '''
    used in self.move() as part of self.calculate_welfare()
    '''

    spice_patch = self.get_spice(pos)
    if spice_patch:
      return spice_patch.amount
    return 0

  def get_trader(self, pos):
      '''
      helper function used in self.trade_with_neighbors()
      '''

      this_cell = self.model.grid.get_cell_list_contents(pos)

      for agent in this_cell:
        if isinstance(agent, Trader):
          return agent


  def is_occupied_by_other(self,pos):
    '''
    helper function part 1 of self.move()
    '''

    if pos == self.pos:
      # agent's position is considered unoccupied as agent can stay there
      return False
    # get contents of each cell in neighborhood
    this_cell = self.model.grid.get_cell_list_contents(pos)
    for a in this_cell:
      # see if occupied by another agent
      if isinstance(a, Trader):
        return True
    return False

  def calculate_welfare(self, sugar, spice):
    '''
    helper function

    part 2 self.move()
    self.trade()
    '''

    # calculate total resources
    m_total = self.metabolism_sugar + self.metabolism_spice
    # Cobb-Douglas functional form; starting on p. 97 on Growing Artificial Societies
    return sugar**(self.metabolism_sugar/m_total) * spice**(
        self.metabolism_spice/m_total)


  def is_starved(self):
    '''
    Helper function for self.maybe_die()
    '''

    return (self.sugar <= 0) or (self.spice <= 0)

  def calculate_MRS(self, sugar, spice):
    '''
    Helper function

    - self.trade()
    - self.maybe_sell_spice

    Determines what trader agent is needs and can give up
    '''

    return (spice/self.metabolism_spice) / (sugar/self.metabolism_sugar)

  def calculate_sell_spice_amount(self, price):
    '''
    helper function for self.maybe_sell_spice() which is called from
    self.trade()
    '''

    if price >= 1:
      sugar = 1
      spice = int(price)
    else:
      sugar = int(1/price)
      spice = 1
    return sugar, spice

  def sell_spice(self, other, sugar, spice):
    '''
    used in self.maybe_sell_spice()

    exchanges sugar and spice between traders
    '''

    self.sugar += sugar
    other.sugar -= sugar
    self.spice -= spice
    other.spice += spice


  def maybe_sell_spice(self, other, price, welfare_self, welfare_other):
    '''
    helper function for self.trade()
    '''

    sugar_exchanged, spice_exchanged = self.calculate_sell_spice_amount(price)

    # Assess new sugar and spice amount - what if change did occur
    self_sugar = self.sugar + sugar_exchanged
    other_sugar = other.sugar - sugar_exchanged
    self_spice = self.spice - spice_exchanged
    other_spice = other.spice + spice_exchanged

    # double check to ensure agents have resources

    if ((self_sugar <= 0) or
        (other_sugar <=0) or
        (self_spice <= 0) or
        (other_spice <= 0)):
      return False

    # trade criteria #1 - are both agents better off?
    both_agents_better_off = (
        (welfare_self < self.calculate_welfare(self_sugar, self_spice)) and
        (welfare_other < other.calculate_welfare(other_sugar, other_spice)))

    # trade criteria #2 is their mrs crossing
    mrs_not_crossing = self.calculate_MRS(self_sugar, self_spice
                                          ) > other.calculate_MRS(
                                              other_sugar, other_spice)

    if not (both_agents_better_off and mrs_not_crossing):
      return False

    # criteria met, execute trade
    self.sell_spice(other, sugar_exchanged, spice_exchanged)

    return True


  def trade(self, other):
    '''
    helper function used in trade_with_neighbors()

    other is a trader agent object
    '''

    # sanity check to verify code is working as expected
    assert self.sugar > 0
    assert self.spice > 0
    assert other.sugar > 0
    assert other.spice > 0

    # calculate marginal rate of subsitution in Growing Artificial Socieites p. 101
    mrs_self = self.calculate_MRS(self.sugar, self.spice)
    mrs_other = other.calculate_MRS(other.sugar, other.spice)

    #calculate each agents welfare
    welfare_self = self.calculate_welfare(self.sugar, self.spice)
    welfare_other = other.calculate_welfare(other.sugar, other.spice)

    if math.isclose(mrs_self, mrs_other):
      return

    # calcualte price
    price = math.sqrt(mrs_self*mrs_other)

    if mrs_self > mrs_other:
      # self is a sugar buyer, spice seller
      sold = self.maybe_sell_spice(other, price, welfare_self, welfare_other)
      # no trade - criteria not met
      if not sold:
        return
    else:
      # self is a spice buyer, sugar seller
      sold = other.maybe_sell_spice(self, price, welfare_other, welfare_self)
      # no trade - criteria not met
      if not sold:
        return

    # Capture data
    self.prices.append(price)
    self.trade_partners.append(other.unique_id)

    # continue trading
    self.trade(other)

  ######################################################################
  #                                                                    #
  #                      MAIN TRADE FUNCTIONS                          #
  #                                                                    #
  ######################################################################


  def move(self):
    '''
    Function for trader agent to identify optimal move for each step in 4 parts
    1 - identify all possible moves
    2 - determine which move maximizes welfare
    3 - find closest best option
    4 - move
    '''

    # 1. identify all possible moves

    neighbors = [i
                 for i in self.model.grid.get_neighborhood(
                   self.pos, self.moore, True, self.vision
                 ) if not self.is_occupied_by_other(i)]

    # 2. determine which move maximizes welfare

    welfares = [
        self.calculate_welfare(
            self.sugar + self.get_sugar_amount(pos),
            self.spice + self.get_spice_amount(pos))
        for pos in neighbors
    ]

    # 3. Find closest best option

    # find the highest welfare in welfares
    max_welfare = max(welfares)
    # get the index of max welfare cells
    candidate_indices = [i for i in range(len(welfares))
                        if math.isclose(welfares[i], max_welfare)]

    # convert index to positions of those cells
    candidates = [neighbors[i] for i in candidate_indices]

    min_dist = min(get_distance(self.pos, pos) for pos in candidates)

    final_candidates = [ pos for pos in candidates
                       if math.isclose(get_distance(self.pos, pos), min_dist, rel_tol=1e-02
                                       )]
    self.random.shuffle(final_candidates)

    # 4. Move Agent
    self.model.grid.move_agent(self, final_candidates[0])

  def eat(self):
    # get sugar
    sugar_patch = self.get_sugar(self.pos)

    if sugar_patch:
        self.sugar += sugar_patch.amount
        sugar_patch.amount = 0
    self.sugar -= self.metabolism_sugar

    # get_spice
    spice_patch = self.get_spice(self.pos)

    if spice_patch:
        self.spice += spice_patch.amount
        spice_patch.amount = 0
    self.spice -= self.metabolism_spice

  def maybe_die(self):
    '''
    Function to remove Traders who have consumed all their sugar or spice
    '''

    if self.is_starved():
      self.model.grid.remove_agent(self)
      self.model.schedule.remove(self)

  def trade_with_neighbors(self):
    '''
    Function for trader agents to decide who to trade with in three parts

    1- identify neighbors who can trade
    2- trade (2 sessions)
    3- collect data
    '''

    neighbor_agents = [self.get_trader(pos) for pos in self.model.grid.get_neighborhood(
        self.pos, self.moore, False, self.vision) if self.is_occupied_by_other(pos)
    ]

    if len(neighbor_agents) == 0:
      return


    # iterate through traders in neighboring cells and trade
    for a in neighbor_agents:
      if a:
        self.trade(a)

    return

# %% [markdown]
# # Model Class

# %%
class SugarscapeG1mt(mesa.Model):
  """
  Manager class to run Sugarscape with Traders
  """


  def __init__(self, width=50,height=50, initial_population=200,
               endowment_min=25, endowment_max=50, metabolism_min=1,
               metabolism_max=5, vision_min=1, vision_max=5):

    #Initiate width and heigh of sugarscape
    self.width = width
    self.height = height
    #Initiate population attributes
    self.initial_population = initial_population
    self.endowment_min = endowment_min
    self.endowment_max = endowment_max
    self.metabolism_min = metabolism_min
    self.metabolism_max = metabolism_max
    self.vision_min = vision_min
    self.vision_max = vision_max

    # initiate activation schedule
    self.schedule = mesa.time.RandomActivationByType(self)
    # initiate mesa grid class
    self.grid = mesa.space.MultiGrid(self.width, self.height, torus=False)
    # initiate datacollector
    self.datacollector = mesa.DataCollector(
        {"Trader": lambda m: m.schedule.get_type_count(Trader),
         "Trade Volume": lambda m: sum(len(a.trade_partners)
         for a in m.schedule.agents_by_type[Trader].values()),
         "Price": lambda m: geometric_mean(flatten([a.prices for a in m.schedule.agents_by_type[Trader].values()]))}
    )


    #read in landscape file from supplmentary material
    sugar_distribution =np.genfromtxt("sugar-map.txt")
    spice_distribution = np.flip(sugar_distribution, 1)

    agent_id = 0
    for _,(x,y) in self.grid.coord_iter():
      max_sugar = sugar_distribution[x,y]
      if max_sugar > 0:
        sugar = Sugar(agent_id, self, (x,y), max_sugar)
        self.schedule.add(sugar)
        self.grid.place_agent(sugar, (x,y))
        agent_id += 1

      max_spice = spice_distribution[x,y]
      if max_spice > 0:
        spice = Spice(agent_id, self, (x,y), max_spice)
        self.schedule.add(spice)
        self.grid.place_agent(spice, (x,y))
        agent_id += 1

    for i in range(self.initial_population):
      #get agent position
      x = self.random.randrange(self.width)
      y = self.random.randrange(self.height)
      #see Growing Artificial Societies p. 108 for initialization
      #give agents initial endowment
      sugar = int(self.random.uniform(self.endowment_min, self.endowment_max+1))
      spice = int(self.random.uniform(self.endowment_min, self.endowment_max+1))
      #give agents initial metabolism
      metabolism_sugar = int(self.random.uniform(self.metabolism_min, self.metabolism_max+1))
      metabolism_spice = int(self.random.uniform(self.metabolism_min, self.metabolism_max+1))
      #give agents vision
      vision = int(self.random.uniform(self.vision_min, self.vision_max+1))
      #create Trader object
      trader = Trader(agent_id,
                      self,
                      (x,y),
                      moore = False,
                      sugar = sugar,
                      spice = spice,
                      metabolism_sugar = metabolism_sugar,
                      metabolism_spice = metabolism_spice,
                      vision = vision)
      #place agent
      self.grid.place_agent(trader, (x,y))
      self.schedule.add(trader)
      agent_id += 1

  def randomize_traders(self):
    '''
    helper function for self.step()

    puts traders in randomized list for step function
    '''

    trader_shuffle = list(self.schedule.agents_by_type[Trader].values())
    self.random.shuffle(trader_shuffle)

    return trader_shuffle


  def step(self):
    '''
    Unique step function that does staged activation of sugar and spice
    and then randomly activates traders
    '''
    # step Sugar agents
    for sugar in self.schedule.agents_by_type[Sugar].values():
      sugar.step()

    # step Spice agents
    for spice in self.schedule.agents_by_type[Spice].values():
      spice.step()

    # step trader agents
    # to account for agent death and removal we need a seperate data strcuture to
    # iterate
    trader_shuffle = self.randomize_traders()

    for agent in trader_shuffle:
      agent.prices = []
      agent.trade_partners = []
      agent.move()
      agent.eat()
      agent.maybe_die()

    trader_shuffle = self.randomize_traders()

    for agent in trader_shuffle:
      agent.trade_with_neighbors()

    self.schedule.steps += 1 #important for data collector to track number of steps

    # collect model level data
    self.datacollector.collect(self)

  def run_model(self, step_count=1000):

    for i in range(step_count):
      self.step()

# %% [markdown]
# # Run Sugarscape

# %%
model = SugarscapeG1mt()
model.run_model()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2914814011.py:9: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 0 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (0, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (0, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (0, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (0, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (0, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (0, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (0, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (0, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (0, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (0, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (0, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (0, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (0, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (0, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (0, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (0, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (0, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (0, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (0, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (0, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (0, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (0, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (1, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (1, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (1, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (1, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (1, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (1, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (1, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (1, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (1, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (1, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (1, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (1, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (1, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (1, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (1, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (1, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (1, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (1, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (1, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (1, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:46: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (2, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:53: UserWarning: Agent 152 is being placed with
# ...
# place_agent() despite already having the position (2, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4294 is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4295 is being placed with
# place_agent() despite already having the position (44, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4296 is being placed with
# place_agent() despite already having the position (39, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4297 is being placed with
# place_agent() despite already having the position (36, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4298 is being placed with
# place_agent() despite already having the position (32, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4299 is being placed with
# place_agent() despite already having the position (22, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4300 is being placed with
# place_agent() despite already having the position (49, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4301 is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4302 is being placed with
# place_agent() despite already having the position (42, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4303 is being placed with
# place_agent() despite already having the position (41, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4304 is being placed with
# place_agent() despite already having the position (13, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4305 is being placed with
# place_agent() despite already having the position (5, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4306 is being placed with
# place_agent() despite already having the position (0, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4307 is being placed with
# place_agent() despite already having the position (1, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4308 is being placed with
# place_agent() despite already having the position (41, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4309 is being placed with
# place_agent() despite already having the position (23, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4310 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4311 is being placed with
# place_agent() despite already having the position (41, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4312 is being placed with
# place_agent() despite already having the position (49, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4313 is being placed with
# place_agent() despite already having the position (21, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4314 is being placed with
# place_agent() despite already having the position (12, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4315 is being placed with
# place_agent() despite already having the position (37, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4316 is being placed with
# place_agent() despite already having the position (9, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4317 is being placed with
# place_agent() despite already having the position (27, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4318 is being placed with
# place_agent() despite already having the position (4, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4319 is being placed with
# place_agent() despite already having the position (47, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4320 is being placed with
# place_agent() despite already having the position (31, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4321 is being placed with
# place_agent() despite already having the position (31, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4322 is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4323 is being placed with
# place_agent() despite already having the position (32, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4324 is being placed with
# place_agent() despite already having the position (31, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4325 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4326 is being placed with
# place_agent() despite already having the position (34, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4327 is being placed with
# place_agent() despite already having the position (41, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4328 is being placed with
# place_agent() despite already having the position (29, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4329 is being placed with
# place_agent() despite already having the position (25, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4330 is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4331 is being placed with
# place_agent() despite already having the position (7, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4332 is being placed with
# place_agent() despite already having the position (40, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4333 is being placed with
# place_agent() despite already having the position (35, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4334 is being placed with
# place_agent() despite already having the position (44, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4335 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4336 is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:80: UserWarning: Agent 4337 is being placed with
# place_agent() despite already having the position (23, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x,y))
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:103: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   for sugar in self.schedule.agents_by_type[Sugar].values():
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:107: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   for spice in self.schedule.agents_by_type[Spice].values():
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:91: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   trader_shuffle = list(self.schedule.agents_by_type[Trader].values())
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:31: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   for a in m.schedule.agents_by_type[Trader].values()),
# C:\Users\HP\AppData\Local\Temp\ipykernel_25136\2202716267.py:32: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   "Price": lambda m: geometric_mean(flatten([a.prices for a in m.schedule.agents_by_type[Trader].values()]))}

# %% [markdown]
# # Analyze Data

# %%
results = model.datacollector.get_model_vars_dataframe()

results
# Out:
#      Trader  Trade Volume     Price
# 0       200           850  1.079909
# 1       200           117  1.060714
# 2       200           149  1.048859
# 3       200            98  1.080966
# 4       200           139  1.168497
# ..      ...           ...       ...
# 995      67             8  1.587123
# 996      67             6  1.423121
# 997      67             8  1.503521
# 998      67             4  0.999378
# 999      67            10  1.286682
#
# [1000 rows x 3 columns]

# %%
# plot number of agents per time step
results.plot(y = "Trader", use_index=True)
# Out:
# <AxesSubplot: >

# %%
# plot trade price per step

y = list(results["Price"])
x = range(1000)

plt.scatter(x,y, s=1)

# %%
# Plot trade volume

plt.bar(results.index[10:], results["Trade Volume"][10:])
# Out:
# <BarContainer object of 990 artists>

# %%
# Plot trade volume improved

for i in range(1000):
  plt.vlines(i,0,results["Trade Volume"][i])
